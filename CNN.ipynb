# %%
import os
from torchvision import datasets, models
from torch.utils.data import ConcatDataset

# %%
path_v1 = './data/Portraits'
path_v2 = './data/Portraits_update'

# %%
weights = models.ResNet50_Weights.DEFAULT
transform = weights.transforms()

# %%
data_v1 = datasets.ImageFolder(root=path_v1, transform=transform)
data_v2 = datasets.ImageFolder(root=path_v2, transform=transform)
full_dataset = ConcatDataset([data_v1, data_v2])

# %%
data_v1 = datasets.ImageFolder(root=path_v1, transform=transform)
data_v2 = datasets.ImageFolder(root=path_v2, transform=transform)
full_dataset = ConcatDataset([data_v1, data_v2])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 data_v1 = datasets.ImageFolder(root=path_v1, transform=transform)
#       2 data_v2 = datasets.ImageFolder(root=path_v2, transform=transform)
#       3 full_dataset = ConcatDataset([data_v1, data_v2])
#
# File c:\Users\Ah\pytorch_amd\Lib\site-packages\torchvision\datasets\folder.py:328, in ImageFolder.__init__(self, root, transform, target_transform, loader, is_valid_file, allow_empty)
#     319 def __init__(
#     320     self,
#     321     root: Union[str, Path],
#    (...)    326     allow_empty: bool = False,
#     327 ):
# --> 328     super().__init__(
#     329         root,
#     330         loader,
#     331         IMG_EXTENSIONS if is_valid_file is None else None,
#     332         transform=transform,
#     333         target_transform=target_transform,
# ...

# %%
train_size = int(0.8 * len(full_dataset))
test_size = len(full_dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(full_dataset, [train_size, test_size])

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
model = models.resnet50(weights=weights)

# %%
for param in model.parameters():
    param.requires_grad = False

# %%
num_styles = len(full_dataset.classes)
model.fc = nn.Linear(model.fc.in_features, num_styles)

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.fc.parameters(), lr=0.001)

# %%
print(f"✅ Success! Loaded {len(full_dataset)} images across {num_styles} styles.")
print(f"🎨 Styles detected: {full_dataset.classes}")
# Out:
# ✅ Success! Loaded 10629 images across 2 styles.
# 🎨 Styles detected: ['Portraits', 'Portraits_update']
